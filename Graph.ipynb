# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabiha1225/Graphs/blob/main/Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt


# creating the dataset
data = {'C':20, 'C++':15, 'Java':30,
        'Python':35}
courses = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)

plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))

# set height of bar
IT = [12, 30, 1, 8, 22]
ECE = [28, 6, 16, 5, 10]
CSE = [29, 3, 24, 25, 17]

# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

# Make the plot
plt.bar(br1, IT, color ='r', width = barWidth,
        edgecolor ='grey', label ='IT')
plt.bar(br2, ECE, color ='g', width = barWidth,
        edgecolor ='grey', label ='ECE')
plt.bar(br3, CSE, color ='b', width = barWidth,
        edgecolor ='grey', label ='CSE')

# Adding Xticks
plt.xlabel('Branch', fontweight ='bold', fontsize = 15)
plt.ylabel('Students passed', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(IT))],
        ['2015', '2016', '2017', '2018', '2019'])

plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# creating the dataset for HAVC
data1 = {'1000':0.00062, '2000':0.00059, '3000': 0.00058,
        '4000':0.00058, '5000':0.00057 }

# creating the dataset for fridge
data2 = {'1000':0.00117, '2000':0.00137, '3000':0.00141,
        '4000':0.00131, '5000':0.00141 }

# creating the dataset for dryer
data3 = {'1000':0.00393, '2000':0.00360, '3000':0.00388,
        '4000':0.00358, '5000':0.00409 }
# creating the dataset for dishwasher
data4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
        '4000':0.00286, '5000':0.00286 }
# creating the dataset for microwave
data5 = {'1000':0.00275, '2000':0.00280, '3000': 0.00280,
        '4000':0.00279, '5000': 0.00281 }
it1 = list(data1.keys())
per1 = list(data1.values())

fig = plt.figure(figsize = (5, 2.5))

# creating the bar plot
plt.bar(it1, per1, color ='#4D78D5',
        width = 0.4)

plt.xlabel("Iteration Number")
plt.ylabel("% of Test Error")
plt.title("HVAC")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# creating the dataset for HAVC CNN--Tree
#data1 = {'1000':0.00062, '2000':0.00059, '3000': 0.00058,
#        '4000':0.00058, '5000':0.00057 }
# creating the dataset for HAVC CNN
#val1 = {'1000': 0.00063, '2000':0.00060, '3000': 0.00059,
#        '4000':0.00059, '5000':0.00059 }

# creating the dataset for fridge CNN--Tree
data2 = {'1000':0.00117, '2000':0.00137, '3000':0.00141,
        '4000':0.00131, '5000':0.00141 }
# creating the dataset for fridge CNN
val2 = {'1000':0.00113, '2000':0.00113, '3000':0.00113,
        '4000':0.00114, '5000':0.00112 }

# creating the dataset for dryer CNN--Tree
data3 = {'1000':0.00393, '2000':0.00360, '3000':0.00388,
        '4000':0.00358, '5000':0.00409 }
# creating the dataset for dryer CNN
val3 = {'1000':0.00239, '2000':0.00236, '3000':0.00237,
        '4000':0.00232, '5000':0.00233 }

# creating the dataset for dishwasher CNN--Tree
data4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
        '4000':0.00286, '5000':0.00286 }
# creating the dataset for dishwasher
val4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
        '4000':0.00286, '5000':0.00286 }

# creating the dataset for microwave CNN--Tree
data5 = {'1000':0.00275, '2000':0.00280, '3000': 0.00280,
        '4000':0.00279, '5000': 0.00281 }
# creating the dataset for microwave
val5 = {'1000': 0.00283, '2000':0.00283, '3000':  0.00284,
        '4000': 0.00284, '5000': 0.00285 }

X = ['1000','2000','3000','4000', '5000']
data1 = [0.00062, 0.00059, 0.00058, 0.00058, 0.00057]
val1 = [0.00063, 0.00060, 0.00059, 0.00059, 0.00059 ]
Ygirls = [10,20,20,40]
Zboys = [20,30,25,30]

X_axis = np.arange(len(X))

fig = plt.figure(figsize = (5, 2.5))
plt.rcParams['font.size'] = '8'
plt.bar(X_axis - 0.2, data1, 0.4, color ='#4D78D5', label = 'CNN-Tree')
plt.bar(X_axis + 0.2, val1, 0.4, color ='#A8C226', label = 'CNN')

plt.xticks(X_axis, X)
plt.xlabel("Iteration Number")
plt.ylabel("% of Test Error")
plt.title("HVAC")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

X = ['Group A','Group B','Group C','Group D']
Ygirls = [10,20,20,40]
Zboys = [20,30,25,30]

X_axis = np.arange(len(X))

plt.bar(X_axis - 0.2, Ygirls, 0.4, label = 'Girls')
plt.bar(X_axis + 0.2, Zboys, 0.4, label = 'Boys')

plt.xticks(X_axis, X)
plt.xlabel("Groups")
plt.ylabel("Number of Students")
plt.title("Number of Students in each group")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# creating the dataset for HAVC
data1 = {'1000':0.00062, '2000':0.00059, '3000': 0.00058,
        '4000':0.00058, '5000':0.00057 }

# creating the dataset for fridge
data2 = {'1000':0.00117, '2000':0.00137, '3000':0.00141,
        '4000':0.00131, '5000':0.00141 }

# creating the dataset for dryer
data3 = {'1000':0.00393, '2000':0.00360, '3000':0.00388,
        '4000':0.00358, '5000':0.00409 }
# creating the dataset for dishwasher
data4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
        '4000':0.00286, '5000':0.00286 }
# creating the dataset for microwave
data5 = {'1000':0.00275, '2000':0.00280, '3000': 0.00280,
        '4000':0.00279, '5000': 0.00281 }
it1 = list(data2.keys())
per1 = list(data2.values())

fig = plt.figure(figsize = (5, 2.5))

# creating the bar plot
plt.bar(it1, per1, color ='#7564DE',
        width = 0.4)

plt.xlabel("Iteration Number")
plt.ylabel("% of Test Error")
plt.title("Fridge")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# creating the dataset for HAVC CNN--Tree
#data1 = {'1000':0.00062, '2000':0.00059, '3000': 0.00058,
#        '4000':0.00058, '5000':0.00057 }
# creating the dataset for HAVC CNN
#val1 = {'1000': 0.00063, '2000':0.00060, '3000': 0.00059,
#        '4000':0.00059, '5000':0.00059 }

# creating the dataset for fridge CNN--Tree
#data2 = {'1000':0.00117, '2000':0.00137, '3000':0.00141,
#        '4000':0.00131, '5000':0.00141 }
# creating the dataset for fridge CNN
#val2 = {'1000':0.00113, '2000':0.00113, '3000':0.00113,
#        '4000':0.00114, '5000':0.00112 }

# creating the dataset for dryer CNN--Tree
data3 = {'1000':0.00393, '2000':0.00360, '3000':0.00388,
        '4000':0.00358, '5000':0.00409 }
# creating the dataset for dryer CNN
val3 = {'1000':0.00239, '2000':0.00236, '3000':0.00237,
        '4000':0.00232, '5000':0.00233 }

# creating the dataset for dishwasher CNN--Tree
data4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
        '4000':0.00286, '5000':0.00286 }
# creating the dataset for dishwasher
val4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
        '4000':0.00286, '5000':0.00286 }

# creating the dataset for microwave CNN--Tree
data5 = {'1000':0.00275, '2000':0.00280, '3000': 0.00280,
        '4000':0.00279, '5000': 0.00281 }
# creating the dataset for microwave
val5 = {'1000': 0.00283, '2000':0.00283, '3000':  0.00284,
        '4000': 0.00284, '5000': 0.00285 }

X = ['1000','2000','3000','4000', '5000']
data2 = [0.00117, 0.00137, 0.00141, 0.00131, 0.00141 ]
val2 = [0.00113, 0.00113, 0.00113, 0.00114, 0.00112 ]

X_axis = np.arange(len(X))

fig = plt.figure(figsize = (5, 2.5))
plt.rcParams['font.size'] = '8'
plt.bar(X_axis - 0.2, data2, 0.4, color ='#7564DE', label = 'CNN-Tree')
plt.bar(X_axis + 0.2, val2, 0.4, color ='#CA5C19', label = 'CNN')

plt.xticks(X_axis, X)
plt.xlabel("Iteration Number")
plt.ylabel("% of Test Error")
plt.title("Fridge")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# creating the dataset for HAVC
data1 = {'1000':0.00062, '2000':0.00059, '3000': 0.00058,
        '4000':0.00058, '5000':0.00057 }

# creating the dataset for fridge
data2 = {'1000':0.00117, '2000':0.00137, '3000':0.00141,
        '4000':0.00131, '5000':0.00141 }

# creating the dataset for dryer
data3 = {'1000':0.00393, '2000':0.00360, '3000':0.00388,
        '4000':0.00358, '5000':0.00409 }
# creating the dataset for dishwasher
data4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
        '4000':0.00286, '5000':0.00286 }
# creating the dataset for microwave
data5 = {'1000':0.00275, '2000':0.00280, '3000': 0.00280,
        '4000':0.00279, '5000': 0.00281 }
it1 = list(data3.keys())
per1 = list(data3.values())

fig = plt.figure(figsize = (5, 2.5))

# creating the bar plot
plt.bar(it1, per1, color ='#6020D9',
        width = 0.4)

plt.xlabel("Iteration Number")
plt.ylabel("% of Test Error")
plt.title("Dryer")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# creating the dataset for HAVC CNN--Tree
#data1 = {'1000':0.00062, '2000':0.00059, '3000': 0.00058,
#        '4000':0.00058, '5000':0.00057 }
# creating the dataset for HAVC CNN
#val1 = {'1000': 0.00063, '2000':0.00060, '3000': 0.00059,
#        '4000':0.00059, '5000':0.00059 }

# creating the dataset for fridge CNN--Tree
#data2 = {'1000':0.00117, '2000':0.00137, '3000':0.00141,
#        '4000':0.00131, '5000':0.00141 }
# creating the dataset for fridge CNN
#val2 = {'1000':0.00113, '2000':0.00113, '3000':0.00113,
#        '4000':0.00114, '5000':0.00112 }

# creating the dataset for dryer CNN--Tree
#data3 = {'1000':0.00393, '2000':0.00360, '3000':0.00388,
#        '4000':0.00358, '5000':0.00409 }
# creating the dataset for dryer CNN
#val3 = {'1000':0.00239, '2000':0.00236, '3000':0.00237,
#        '4000':0.00232, '5000':0.00233 }

# creating the dataset for dishwasher CNN--Tree
data4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
        '4000':0.00286, '5000':0.00286 }
# creating the dataset for dishwasher
val4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
        '4000':0.00286, '5000':0.00286 }

# creating the dataset for microwave CNN--Tree
data5 = {'1000':0.00275, '2000':0.00280, '3000': 0.00280,
        '4000':0.00279, '5000': 0.00281 }
# creating the dataset for microwave
val5 = {'1000': 0.00283, '2000':0.00283, '3000':  0.00284,
        '4000': 0.00284, '5000': 0.00285 }

X = ['1000','2000','3000','4000', '5000']
data3 = [0.00393, 0.00360, 0.00388, 0.00358, 0.00409]
val3 = [0.00239, 0.00236, 0.00237, 0.00232, 0.00233]

X_axis = np.arange(len(X))

fig = plt.figure(figsize = (5, 2.5))
plt.rcParams['font.size'] = '8'
plt.bar(X_axis - 0.2, data3, 0.4, color ='#6020D9', label = 'CNN-Tree')
plt.bar(X_axis + 0.2, val3, 0.4, color ='#AD1FC3', label = 'CNN')

plt.xticks(X_axis, X)
plt.xlabel("Iteration Number")
plt.ylabel("% of Test Error")
plt.title("Dryer")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# creating the dataset for HAVC
data1 = {'1000':0.00062, '2000':0.00059, '3000': 0.00058,
        '4000':0.00058, '5000':0.00057 }

# creating the dataset for fridge
data2 = {'1000':0.00117, '2000':0.00137, '3000':0.00141,
        '4000':0.00131, '5000':0.00141 }

# creating the dataset for dryer
data3 = {'1000':0.00393, '2000':0.00360, '3000':0.00388,
        '4000':0.00358, '5000':0.00409 }
# creating the dataset for dishwasher
data4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
        '4000':0.00286, '5000':0.00286 }
# creating the dataset for microwave
data5 = {'1000':0.00275, '2000':0.00280, '3000': 0.00280,
        '4000':0.00279, '5000': 0.00281 }
it1 = list(data4.keys())
per1 = list(data4.values())

fig = plt.figure(figsize = (5, 2.5))

# creating the bar plot
plt.bar(it1, per1, color ='#20A4D9',
        width = 0.4)

plt.xlabel("Iteration Number")
plt.ylabel("% of Test Error")
plt.title("Dishwasher")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# creating the dataset for HAVC CNN--Tree
#data1 = {'1000':0.00062, '2000':0.00059, '3000': 0.00058,
#        '4000':0.00058, '5000':0.00057 }
# creating the dataset for HAVC CNN
#val1 = {'1000': 0.00063, '2000':0.00060, '3000': 0.00059,
#        '4000':0.00059, '5000':0.00059 }

# creating the dataset for fridge CNN--Tree
#data2 = {'1000':0.00117, '2000':0.00137, '3000':0.00141,
#        '4000':0.00131, '5000':0.00141 }
# creating the dataset for fridge CNN
#val2 = {'1000':0.00113, '2000':0.00113, '3000':0.00113,
#        '4000':0.00114, '5000':0.00112 }

# creating the dataset for dryer CNN--Tree
#data3 = {'1000':0.00393, '2000':0.00360, '3000':0.00388,
#        '4000':0.00358, '5000':0.00409 }
# creating the dataset for dryer CNN
#val3 = {'1000':0.00239, '2000':0.00236, '3000':0.00237,
#        '4000':0.00232, '5000':0.00233 }

# creating the dataset for dishwasher CNN--Tree
#data4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
#        '4000':0.00286, '5000':0.00286 }
# creating the dataset for dishwasher
#val4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
#        '4000':0.00286, '5000':0.00286 }

# creating the dataset for microwave CNN--Tree
data5 = {'1000':0.00275, '2000':0.00280, '3000': 0.00280,
        '4000':0.00279, '5000': 0.00281 }
# creating the dataset for microwave
val5 = {'1000': 0.00283, '2000':0.00283, '3000':  0.00284,
        '4000': 0.00284, '5000': 0.00285 }

X = ['1000','2000','3000','4000', '5000']
data4 = [0.00286, 0.00286, 0.00286, 0.00286, 0.00286]
val4 = [0.00286, 0.00286, 0.00286, 0.00286, 0.00286]

X_axis = np.arange(len(X))

fig = plt.figure(figsize = (5, 2.5))
plt.rcParams['font.size'] = '8'
plt.bar(X_axis - 0.2, data4, 0.4, color ='#20A4D9', label = 'CNN-Tree')
plt.bar(X_axis + 0.2, val4, 0.4, color ='#D58B10', label = 'CNN')

plt.xticks(X_axis, X)
plt.xlabel("Iteration Number")
plt.ylabel("% of Test Error")
plt.title("Dishwasher")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# creating the dataset for HAVC
data1 = {'1000':0.00062, '2000':0.00059, '3000': 0.00058,
        '4000':0.00058, '5000':0.00057 }

# creating the dataset for fridge
data2 = {'1000':0.00117, '2000':0.00137, '3000':0.00141,
        '4000':0.00131, '5000':0.00141 }

# creating the dataset for dryer
data3 = {'1000':0.00393, '2000':0.00360, '3000':0.00388,
        '4000':0.00358, '5000':0.00409 }
# creating the dataset for dishwasher
data4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
        '4000':0.00286, '5000':0.00286 }
# creating the dataset for microwave
data5 = {'1000':0.00275, '2000':0.00280, '3000': 0.00280,
        '4000':0.00279, '5000': 0.00281 }
it1 = list(data5.keys())
per1 = list(data5.values())

fig = plt.figure(figsize = (5, 2.5))

# creating the bar plot
plt.bar(it1, per1, color ='#0789BE',
        width = 0.4)

plt.xlabel("Iteration Number")
plt.ylabel("% of Test Error")
plt.title("Microwave")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# creating the dataset for HAVC CNN--Tree
#data1 = {'1000':0.00062, '2000':0.00059, '3000': 0.00058,
#        '4000':0.00058, '5000':0.00057 }
# creating the dataset for HAVC CNN
#val1 = {'1000': 0.00063, '2000':0.00060, '3000': 0.00059,
#        '4000':0.00059, '5000':0.00059 }

# creating the dataset for fridge CNN--Tree
#data2 = {'1000':0.00117, '2000':0.00137, '3000':0.00141,
#        '4000':0.00131, '5000':0.00141 }
# creating the dataset for fridge CNN
#val2 = {'1000':0.00113, '2000':0.00113, '3000':0.00113,
#        '4000':0.00114, '5000':0.00112 }

# creating the dataset for dryer CNN--Tree
#data3 = {'1000':0.00393, '2000':0.00360, '3000':0.00388,
#        '4000':0.00358, '5000':0.00409 }
# creating the dataset for dryer CNN
#val3 = {'1000':0.00239, '2000':0.00236, '3000':0.00237,
#        '4000':0.00232, '5000':0.00233 }

# creating the dataset for dishwasher CNN--Tree
#data4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
#        '4000':0.00286, '5000':0.00286 }
# creating the dataset for dishwasher
#val4 = {'1000':0.00286, '2000':0.00286, '3000':0.00286,
#        '4000':0.00286, '5000':0.00286 }

# creating the dataset for microwave CNN--Tree
#data5 = {'1000':0.00275, '2000':0.00280, '3000': 0.00280,
#       '4000':0.00279, '5000': 0.00281 }
# creating the dataset for microwave
#val5 = {'1000': 0.00283, '2000':0.00283, '3000':  0.00284,
#        '4000': 0.00284, '5000': 0.00285 }

X = ['1000','2000','3000','4000', '5000']
data5 = [0.00275, 0.00280, 0.00280, 0.00279, 0.00281]
val5 = [0.00283, 0.00283, 0.00284, 0.00284, 0.00285]

X_axis = np.arange(len(X))

fig = plt.figure(figsize = (5, 2.5))
plt.rcParams['font.size'] = '8'
plt.bar(X_axis - 0.2, data5, 0.4, color ='#0789BE', label = 'CNN-Tree')
plt.bar(X_axis + 0.2, val5, 0.4, color ='#958C05', label = 'CNN')

plt.xticks(X_axis, X)
plt.xlabel("Iteration Number")
plt.ylabel("% of Test Error")
plt.title("Microwave")
plt.legend()
plt.show()
